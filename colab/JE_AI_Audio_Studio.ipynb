# %% [markdown]
# # 🎚️ JE AI Audio Studio — Google Colab
#
# Crash-resistant setup for Android/Colab development. The base app stays lightweight; this notebook optionally installs neural Basic Pitch, DeepFilterNet, and torchcrepe backends.

# %%
import os, sys, platform
print('Python:', sys.version)
print('Platform:', platform.platform())
print('Working directory:', os.getcwd())

# %%
# Clone or refresh the project. Safe to re-run.
repo = '/content/JE-AI-Audio-Studio'
if not os.path.exists(repo):
    # !git clone https://github.com/jejamalodasi/JE-AI-Audio-Studio.git $repo
else:
    # %cd $repo
    # !git fetch origin main
    # !git reset --hard origin/main
# %cd $repo
# !git rev-parse --short HEAD

# %%
# Install the stable base stack first, then optional neural AI dependencies.
# !python -m pip install -q --upgrade pip
# !python -m pip install -q -r requirements.txt
# !python -m pip install -q -r requirements-ai.txt
print('Dependencies installed.')

# %%
# PyTorch is required by DeepFilterNet/torchcrepe. Colab normally already has it.
try:
    import torch
    print('✅ PyTorch:', torch.__version__)
except ImportError:
    # !python -m pip install -q torch
    import torch
    print('✅ PyTorch installed:', torch.__version__)

# %%
# Import smoke test. This does not run heavy inference or download model weights.
from app import build_app
from ai.basic_pitch_transcriber import transcribe_with_basic_pitch
from ai.neural_vocal_enhancement import enhance_vocal_neural
from ai.pitch_timing_ai import correct_pitch_timing_ai
from ai.arrangement_generator import generate_ai_conditioned_arrangement
print('✅ App imports successfully')
print('✅ Basic Pitch wrapper imports successfully')
print('✅ DeepFilterNet wrapper imports successfully')
print('✅ Neural pitch/timing wrapper imports successfully')
print('✅ AI conditioned arrangement imports successfully')

# %%
# Optional lightweight pipeline smoke test using pYIN fallback; no neural model inference.
import numpy as np, soundfile as sf
from ai.arrangement_generator import AIConditionedArrangementConfig
sr = 22050
t = np.arange(sr * 2) / sr
demo_path = '/content/je_ai_smoke.wav'
sf.write(demo_path, 0.15 * np.sin(2 * np.pi * 220.0 * t).astype(np.float32), sr)
result = generate_ai_conditioned_arrangement(demo_path, config=AIConditionedArrangementConfig(bars=2, melody_backend='pyin'))
print('✅ Conditioned arrangement smoke test:', result['bpm'], result['key'], result['scale'], result['melody_backend'])

# %%
# Launch the Gradio app with a public temporary share URL.
# Keep this cell running while using the studio.
demo = build_app()
demo.launch(share=True, show_error=True, debug=False)
